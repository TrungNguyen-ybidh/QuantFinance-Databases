# %%
import pandas as pd
from dotenv import load_dotenv
from fetchers import Fetcher
from config import fmp_endpoints, ROOT, schema_map
from cleaners import parse_dict_col, keep_and_rename
import glob
import os

# %%
df = pd.read_csv(f"{ROOT}/data/raw/daily_price/daily_price.csv", low_memory=False)
df.head()
# Out:
#    Unnamed: 0        Date Ticker  Adj Close  Close  High   Low  Open  Volume
# 0           0  2016-03-28  PTIZF        inf   0.45  0.45  0.45  0.45     0.0
# 1           1  2016-03-28  TTFNF        NaN    NaN   NaN   NaN   NaN     NaN
# 2           2  2016-03-28   ZYXI        NaN    NaN   NaN   NaN   NaN     NaN
# 3           3  2016-03-28   AAUC        NaN    NaN   NaN   NaN   NaN     NaN
# 4           4  2016-03-28  AAYYY        NaN    NaN   NaN   NaN   NaN     NaN

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 44668575 entries, 0 to 44668574
# Data columns (total 9 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   Unnamed: 0  int64
#  1   Date        str
#  2   Ticker      str
#  3   Adj Close   float64
#  4   Close       float64
#  5   High        float64
#  6   Low         float64
#  7   Open        float64
#  8   Volume      float64
# dtypes: float64(6), int64(1), str(2)
# memory usage: 3.6 GB

# %%
df_clean = df.drop(columns=['Adj Close', 'Unnamed: 0'])
df_clean['Date'] = pd.to_datetime(df_clean['Date'])
df_clean.columns = df_clean.columns.str.lower()

# %%
df_clean = df_clean.dropna(axis=0)

# %%
df_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 30377706 entries, 0 to 44668574
# Data columns (total 7 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   date    datetime64[us]
#  1   ticker  str
#  2   close   float64
#  3   high    float64
#  4   low     float64
#  5   open    float64
#  6   volume  float64
# dtypes: datetime64[us](1), float64(5), str(1)
# memory usage: 1.9 GB

# %%
df_clean.to_csv(f"{ROOT}/data/raw/daily_price/cleaned/daily_price.csv")
