# %%
import pandas as pd
from dotenv import load_dotenv
from fetchers import Fetcher
from config import fmp_endpoints, engine, ROOT, schema_map
from sqlalchemy import text
from cleaners import parse_dict_col, keep_and_rename
import glob
import os
# Out:
# (1,)

# %%
csv_to_table = {
    "quote.csv":                            "quotes",
    "financial-scores.csv":                 "scores",
    "discounted-cash-flow.csv":             "dcf",
    "levered-discounted-cash-flow.csv":     "dcf_levered",
    "income-statement.csv":                 "income_stmt",
    "balance-sheet-statement.csv":          "balance_sheet",
    "cash-flow-statement.csv":              "cashflow",
    "cash-flow-statement-growth.csv":       "cashflow_growth",
    "income-statement-growth.csv":          "income_stmt_growth",
    "key-metrics.csv":                      "metrics",
    "ratios.csv":                           "ratios",
    "financial-growth.csv":                 "growth",
    "enterprise-values.csv":                "ev",
    "dividends.csv":                        "dividends",
    "ratings-historical.csv":               "ratings",
}

# %%
def data_cleaning(df):
    existing = pd.read_sql("SELECT ticker FROM companies", engine)
    date_cols = [col for col in df.columns if 'date' in col.lower()]
    df_clean = df[df['ticker'].isin(existing['ticker'])].copy()
    
    for col in date_cols:
        df_clean[col] = pd.to_datetime(df_clean[col], errors='coerce')
    
    if 'period' in df.columns and 'date' in df.columns:
        df_clean = df_clean.drop_duplicates(subset=['ticker', 'date', 'period'], keep='first')
    elif 'date' in df.columns:
        df_clean = df_clean.drop_duplicates(subset=['ticker', 'date'], keep='first')
    else:
        df_clean = df_clean.drop_duplicates()
    
    return df_clean

# %%
def insert_to_sql(table, file=None, df=None):
    if df is None and file is not None:
        df = pd.read_csv(f"{ROOT}/data/cleanned/{file}")
        print(f"{file}: {list(df.columns)}")
        df_clean = data_cleaning(df)
    elif df is None and file is not None:
        print(f"{file}: {list(df.columns)}")
        df_clean = data_cleaning(df)

    with engine.connect() as conn:
        conn.execute(text(f"TRUNCATE TABLE {table}"))
        conn.commit()

    df_clean.to_sql(table, engine, if_exists='append', index=False)

# %%
for file, table in csv_to_table.items():
    df = pd.read_csv(f"{ROOT}/data/cleanned/{file}", low_memory=False)
    db_count = pd.read_sql(text(f"SELECT COUNT(*) as cnt FROM {table}"), engine).iloc[0, 0]
    print(f"{table}: CSV={len(df)} | DB={db_count}")
# Out:
# quotes: CSV=17776 | DB=17774
# scores: CSV=16506 | DB=16504
# dcf: CSV=17108 | DB=17106
# dcf_levered: CSV=17108 | DB=17106
# income_stmt: CSV=450242 | DB=450161
# balance_sheet: CSV=441570 | DB=441490
# cashflow: CSV=443104 | DB=443030
# cashflow_growth: CSV=295130 | DB=295074
# income_stmt_growth: CSV=299985 | DB=299937
# metrics: CSV=297626 | DB=297581
# ratios: CSV=297663 | DB=297619
# growth: CSV=300862 | DB=300817
# ev: CSV=297781 | DB=297736
# dividends: CSV=146282 | DB=146237
# ratings: CSV=16190 | DB=16188
