# %%
import requests
import pandas as pd
import time
from dotenv import load_dotenv
import os
from sqlalchemy import create_engine, text

# %%
engine = create_engine("mysql+pymysql://root:Aatroxkalistartop123@localhost:3306/finance_db")

# %%
load_dotenv()
api_key = os.getenv('FMP_api')

# %%
def fetch_data(url, name=''):
    response = requests.get(url)
    df = pd.DataFrame(response.json())
    return df.to_csv(name)

# %%
def fetch_fmp_comp_info(symbol_list, api_key):
    url = 'https://financialmodelingprep.com/stable/profile'
    dfs = []
    
    for i, symbol in enumerate(symbol_list):  
        response = requests.get(url, params={'symbol': symbol, 'apikey': api_key})
        data = response.json()
        
        if not data:
            print(f"No data for {symbol}")
            continue
        
        dfs.append(pd.DataFrame(data))
        time.sleep(0.171)
        
        if (i + 1) % 100 == 0:
            print(f"Progress: {i + 1} / {len(symbol_list)} fetched...")
    
    if not dfs:
        return pd.DataFrame()
    
    df = pd.concat(dfs, ignore_index=True)
    
    df_clean = df[[
        "cik", "symbol", "companyName", "sector", "industry",
        "exchange", "country", "currency", "marketCap",
        "ipoDate", "isActivelyTrading", "isEtf", "isAdr", "isFund"
    ]].rename(columns={
        "symbol":            "ticker",
        "companyName":       "name",
        "marketCap":         "market_cap",
        "ipoDate":           "ipo_date",
        "isActivelyTrading": "is_active",
        "isEtf":             "is_etf",
        "isAdr":             "is_adr",
        "isFund":            "is_fund"
    })               
    
    return df_clean

# %%
# load all lists
stock_list    = pd.read_csv("stock_list.csv")
active        = pd.read_csv("active_trading.csv")
etf_list      = pd.read_csv("ETF_list.csv")
fin_list      = pd.read_csv("financial_statement_list.csv")

symbols = active["symbol"].tolist()

etf_symbols = etf_list["symbol"].tolist()
symbols = [s for s in symbols if s not in etf_symbols]

fin_symbols = fin_list["symbol"].tolist()
symbols = [s for s in symbols if s in fin_symbols]

# %%
def fetch_income_statement(symbol_lst, api_key, period='quarter', limit=20, time_sleep=0.171):
    url = 'https://financialmodelingprep.com/stable/income-statement'
    dfs = []
    for i, symbol in enumerate(symbol_lst):  
        params = {
            'symbol' : symbol,
            'limit': limit,
            'period': period,
            'apikey': api_key
        }
        response = requests.get(url, params = params)
        data = response.json()

        dfs.append(pd.DataFrame(data))
        time.sleep(time_sleep)

        if (i + 1) % 100 == 0:
            print(f"Progress: {i + 1} / {len(symbol_lst)} fetched...")
    
    if not dfs:
        return pd.DataFrame()

    df = pd.concat(dfs, ignore_index=True)
    df_clean = df[[
            "cik",
            "symbol",           
            "date",             
            "period",           
            "revenue",
            "costOfRevenue",    
            "grossProfit",      
            "operatingExpenses",
            "operatingIncome",  
            "netIncome",        
            "ebitda",
            "eps",
            "weightedAverageShsOut",      
            
            "fiscalYear",                 
            "depreciationAndAmortization",
            "incomeTaxExpense",           
            "incomeBeforeTax",            
            "interestExpense"             
        ]].rename(columns={
            "symbol":                     "ticker",
            "date":                       "period_date",
            "period":                     "period_type",
            "costOfRevenue":              "cost_of_revenue",
            "grossProfit":                "gross_profit",
            "operatingExpenses":          "operating_expense",
            "operatingIncome":            "operating_income",
            "netIncome":                  "net_income",
            "weightedAverageShsOut":      "shares_outstanding",
            "fiscalYear":                 "fiscal_year",
            "depreciationAndAmortization":"depreciation_amortization",
            "incomeTaxExpense":           "income_tax_expense",
            "incomeBeforeTax":            "income_before_tax",
            "interestExpense":            "interest_expense"
        })
    
    df_clean = df_clean.drop_duplicates(subset=["cik", "period_date"], keep="first")
    df_clean["cik"] = df_clean["cik"].replace('null', pd.NA)
    df_clean = df_clean.dropna(subset=["cik"])  
    df_clean["cik"] = df_clean["cik"].astype(int)
    df_clean["period_type"] = df_clean["period_type"].map(
    lambda x: "annual" if x == "FY" else "quarterly"
    )

    return df_clean

# %%
def fetch_balance_sheet(symbol_lst, api_key, period='quarter', limit=20, time_sleep=0.171):
    url = 'https://financialmodelingprep.com/stable/balance-sheet-statement'
    dfs = []
    
    for i, symbol in enumerate(symbol_lst):
        params = {
            'symbol': symbol,
            'limit':  limit,
            'period': period,
            'apikey': api_key
        }
        response = requests.get(url, params=params)
        data = response.json()
        
        if not data:
            print(f"No data for {symbol}")
            continue
        
        dfs.append(pd.DataFrame(data))
        time.sleep(time_sleep)
        
        if (i + 1) % 100 == 0:
            print(f"Progress: {i + 1} / {len(symbol_lst)} fetched...")
    
    if not dfs:
        return pd.DataFrame()
    
    df = pd.concat(dfs, ignore_index=True)
    
    df_clean = df[[
        "cik", "symbol", "date", "period", "fiscalYear",
        "cashAndCashEquivalents", "shortTermInvestments",
        "totalCurrentAssets", "totalAssets", "totalCurrentLiabilities",
        "totalLiabilities", "totalEquity", "totalDebt", "netDebt",
        "retainedEarnings", "goodwill", "intangibleAssets",
        "propertyPlantEquipmentNet", "longTermDebt", "shortTermDebt",
        "totalStockholdersEquity", "accountPayables", "inventory"
    ]].rename(columns={
        "symbol":                   "ticker",
        "date":                     "period_date",
        "period":                   "period_type",
        "fiscalYear":               "fiscal_year",
        "cashAndCashEquivalents":   "cash",
        "shortTermInvestments":     "short_term_investment",
        "totalCurrentAssets":       "total_current_asset",
        "totalAssets":              "total_assets",
        "totalCurrentLiabilities":  "total_current_liabilities",
        "totalLiabilities":         "total_liabilities",
        "totalEquity":              "total_equity",
        "totalDebt":                "total_debt",
        "netDebt":                  "net_debt",
        "retainedEarnings":         "retained_earnings",
        "goodwill":                 "goodwill",
        "intangibleAssets":         "intangible_assets",
        "propertyPlantEquipmentNet":"ppe_net",
        "longTermDebt":             "long_term_debt",
        "shortTermDebt":            "short_term_debt",
        "totalStockholdersEquity":  "stockholders_equity",
        "accountPayables":          "accounts_payable",
        "inventory":                "inventory"
    })
    
    df_clean["period_type"] = df_clean["period_type"].map(
        lambda x: "annual" if x == "FY" else "quarterly"
    )
    df_clean = df_clean.dropna(subset=["cik"])
    df_clean["cik"] = df_clean["cik"].astype(int)
    
    return df_clean

# %%
def fetch_cash_flow(symbol_lst, api_key, period='quarter', limit=20, time_sleep=0.171):
    url = 'https://financialmodelingprep.com/stable/cash-flow-statement'
    dfs = []
    
    for i, symbol in enumerate(symbol_lst):
        params = {
            'symbol': symbol,
            'limit':  limit,
            'period': period,
            'apikey': api_key
        }
        response = requests.get(url, params=params)
        data = response.json()
        
        if not data:
            print(f"No data for {symbol}")
            continue
        
        dfs.append(pd.DataFrame(data))
        time.sleep(time_sleep)
        
        if (i + 1) % 100 == 0:
            print(f"Progress: {i + 1} / {len(symbol_lst)} fetched...")
    
    if not dfs:
        return pd.DataFrame()
    
    df = pd.concat(dfs, ignore_index=True)
    
    df_clean = df[[
        "cik", "symbol", "date", "period", "fiscalYear",
        "operatingCashFlow",
        "netCashProvidedByInvestingActivities",
        "netCashProvidedByFinancingActivities",
        "freeCashFlow",
        "capitalExpenditure",
        "commonDividendsPaid",
        "netChangeInCash",
        "netIncome",
        "depreciationAndAmortization",
        "stockBasedCompensation"
    ]].rename(columns={
        "symbol":                               "ticker",
        "date":                                 "period_date",
        "period":                               "period_type",
        "fiscalYear":                           "fiscal_year",
        "operatingCashFlow":                    "operating_cash_flow",
        "netCashProvidedByInvestingActivities": "investing_cash_flow",
        "netCashProvidedByFinancingActivities": "financing_cash_flow",
        "freeCashFlow":                         "free_cash_flow",
        "capitalExpenditure":                   "capex",
        "commonDividendsPaid":                  "dividends_paid",
        "netChangeInCash":                      "net_change_in_cash",
        "netIncome":                            "net_income",
        "depreciationAndAmortization":          "depreciation_amortization",
        "stockBasedCompensation":               "stock_based_compensation"
    })
    
    df_clean["period_type"] = df_clean["period_type"].map(
        lambda x: "annual" if x == "FY" else "quarterly"
    )
    df_clean = df_clean.dropna(subset=["cik"])
    df_clean["cik"] = df_clean["cik"].astype(int)
    
    return df_clean

# %%
income_df = fetch_income_statement(symbols, api_key)
income_df.to_csv("income_statement.csv")
# Out:
# Progress: 100 / 17776 fetched...
# Progress: 200 / 17776 fetched...
# Progress: 300 / 17776 fetched...
# Progress: 400 / 17776 fetched...
# Progress: 500 / 17776 fetched...
# Progress: 600 / 17776 fetched...
# Progress: 700 / 17776 fetched...
# Progress: 800 / 17776 fetched...
# Progress: 900 / 17776 fetched...
# Progress: 1000 / 17776 fetched...
# Progress: 1100 / 17776 fetched...
# Progress: 1200 / 17776 fetched...
# Progress: 1300 / 17776 fetched...
# Progress: 1400 / 17776 fetched...
# Progress: 1500 / 17776 fetched...
# Progress: 1600 / 17776 fetched...
# Progress: 1700 / 17776 fetched...
# Progress: 1800 / 17776 fetched...
# Progress: 1900 / 17776 fetched...
# Progress: 2000 / 17776 fetched...
# Progress: 2100 / 17776 fetched...
# Progress: 2200 / 17776 fetched...
# Progress: 2300 / 17776 fetched...
# Progress: 2400 / 17776 fetched...
# Progress: 2500 / 17776 fetched...
# Progress: 2600 / 17776 fetched...
# Progress: 2700 / 17776 fetched...
# Progress: 2800 / 17776 fetched...
# Progress: 2900 / 17776 fetched...
# Progress: 3000 / 17776 fetched...
# Progress: 3100 / 17776 fetched...
# Progress: 3200 / 17776 fetched...
# Progress: 3300 / 17776 fetched...
# Progress: 3400 / 17776 fetched...
# Progress: 3500 / 17776 fetched...
# Progress: 3600 / 17776 fetched...
# Progress: 3700 / 17776 fetched...
# Progress: 3800 / 17776 fetched...
# Progress: 3900 / 17776 fetched...
# Progress: 4000 / 17776 fetched...
# Progress: 4100 / 17776 fetched...
# Progress: 4200 / 17776 fetched...
# Progress: 4300 / 17776 fetched...
# Progress: 4400 / 17776 fetched...
# Progress: 4500 / 17776 fetched...
# Progress: 4600 / 17776 fetched...
# Progress: 4700 / 17776 fetched...
# Progress: 13200 / 17776 fetched...
# Progress: 13300 / 17776 fetched...
# Progress: 13400 / 17776 fetched...
# Progress: 13500 / 17776 fetched...
# Progress: 13600 / 17776 fetched...
# Progress: 13700 / 17776 fetched...
# Progress: 13800 / 17776 fetched...
# Progress: 13900 / 17776 fetched...
# Progress: 14000 / 17776 fetched...
# Progress: 14100 / 17776 fetched...
# Progress: 14200 / 17776 fetched...
# Progress: 14300 / 17776 fetched...
# Progress: 14400 / 17776 fetched...
# Progress: 14500 / 17776 fetched...
# Progress: 14600 / 17776 fetched...
# Progress: 14700 / 17776 fetched...
# Progress: 14800 / 17776 fetched...
# Progress: 14900 / 17776 fetched...
# Progress: 15000 / 17776 fetched...
# Progress: 15100 / 17776 fetched...
# Progress: 15200 / 17776 fetched...
# Progress: 15300 / 17776 fetched...
# Progress: 15400 / 17776 fetched...
# Progress: 15500 / 17776 fetched...
# Progress: 15600 / 17776 fetched...
# Progress: 15700 / 17776 fetched...
# Progress: 15800 / 17776 fetched...
# Progress: 15900 / 17776 fetched...
# Progress: 16000 / 17776 fetched...
# Progress: 16100 / 17776 fetched...
# Progress: 16200 / 17776 fetched...
# Progress: 16300 / 17776 fetched...
# Progress: 16400 / 17776 fetched...
# Progress: 16500 / 17776 fetched...
# Progress: 16600 / 17776 fetched...
# Progress: 16700 / 17776 fetched...
# Progress: 16800 / 17776 fetched...
# Progress: 16900 / 17776 fetched...
# Progress: 17000 / 17776 fetched...
# Progress: 17100 / 17776 fetched...
# Progress: 17200 / 17776 fetched...
# Progress: 17300 / 17776 fetched...
# Progress: 17400 / 17776 fetched...
# Progress: 17500 / 17776 fetched...
# Progress: 17600 / 17776 fetched...
# Progress: 17700 / 17776 fetched...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 income_df = fetch_income_statement(symbols, api_key)
#       2 income_df.to_csv("income_statement.csv")
#
# Cell In[7], line 62, in fetch_income_statement(symbol_lst, api_key, period, limit, time_sleep)
#      60 df_clean = df_clean.drop_duplicates(subset=["cik", "period_date"], keep="first")
#      61 df_clean = df_clean.dropna(subset=["cik"])
# ---> 62 df_clean["cik"] = df_clean["cik"].astype(int)
#      63 df_clean["period_type"] = df_clean["period_type"].map(
#      64 lambda x: "annual" if x == "FY" else "quarterly"
#      65 )
#      67 return df_clean
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pandas/core/generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pandas/core/internals/managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# --> 611     return self.apply("astype", dtype=dtype, errors=errors)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pandas/core/internals/managers.py:442, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     440         applied = b.apply(f, **kwargs)
#     441     else:
# --> 442         applied = getattr(b, f)(**kwargs)
#     443     result_blocks = extend_blocks(applied, result_blocks)
#     445 out = type(self).from_blocks(result_blocks, [ax.view() for ax in self.axes])
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pandas/core/internals/blocks.py:607, in Block.astype(self, dtype, errors, squeeze)
#     604         raise ValueError("Can not squeeze with more than one column.")
#     605     values = values[0, :]  # type: ignore[call-overload]
# --> 607 new_values = astype_array_safe(values, dtype, errors=errors)
#     609 new_values = maybe_coerce_values(new_values)
#     611 refs = None
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pandas/core/dtypes/astype.py:240, in astype_array_safe(values, dtype, copy, errors)
#     237     dtype = dtype.numpy_dtype
#     239 try:
# --> 240     new_values = astype_array(values, dtype, copy=copy)
#     241 except (ValueError, TypeError):
#     242     # e.g. _astype_nansafe can fail on object-dtype of strings
#     243     #  trying to convert to float
#     244     if errors == "ignore":
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pandas/core/dtypes/astype.py:182, in astype_array(values, dtype, copy)
#     178     return values
#     180 if not isinstance(values, np.ndarray):
#     181     # i.e. ExtensionArray
# --> 182     values = values.astype(dtype, copy=copy)
#     184 else:
#     185     values = _astype_nansafe(values, dtype, copy=copy)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pandas/core/arrays/string_arrow.py:330, in ArrowStringArray.astype(self, dtype, copy)
#     327 elif isinstance(dtype, np.dtype) and np.issubdtype(dtype, np.floating):
#     328     return self.to_numpy(dtype=dtype, na_value=np.nan)
# --> 330 return super().astype(dtype, copy=copy)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pandas/core/arrays/base.py:881, in ExtensionArray.astype(self, dtype, copy)
#     878     return TimedeltaArray._from_sequence(self, dtype=dtype, copy=copy)
#     880 if not copy:
# --> 881     return np.asarray(self, dtype=dtype)
#     882 else:
#     883     return np.array(self, dtype=dtype, copy=copy)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pandas/core/arrays/arrow/array.py:864, in ArrowExtensionArray.__array__(self, dtype, copy)
#     860 elif copy is None:
#     861     # `to_numpy(copy=False)` has the meaning of NumPy `copy=None`.
#     862     copy = False
# --> 864 return self.to_numpy(dtype=dtype, copy=copy)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pandas/core/arrays/arrow/array.py:1717, in ArrowExtensionArray.to_numpy(self, dtype, copy, na_value)
#    1715 result = data._pa_array.to_numpy()
#    1716 if dtype is not None:
# -> 1717     result = result.astype(dtype, copy=False)
#    1718 if copy:
#    1719     result = result.copy()
#
# ValueError: invalid literal for int() with base 10: 'null'
