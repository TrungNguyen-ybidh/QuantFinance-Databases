# %%
import requests
import pandas as pd
from sqlalchemy import create_engine, text

# %%
engine = create_engine("mysql+pymysql://root:Aatroxkalistartop123@localhost:3306/finance_db")

# %%
api_key = 'o9NfoSRmyQfE5ipiaKS7jku9n5C6G1dV'
url = 'https://financialmodelingprep.com/stable/income-statement'

params = {
    'symbol':'NVDA',
    'period':'quarter',
    'apikey': api_key
}

response = requests.get(url, params=params)

# %%
api_key = 'o9NfoSRmyQfE5ipiaKS7jku9n5C6G1dV'

def fetch_fmp_comp_info(symbol_list, api_key=''):
    url = 'https://financialmodelingprep.com/stable/profile'
    dfs = []
    
    for symbol in symbol_list:
        params = {
            'symbol': symbol,
            'apikey': api_key
        }
        response = requests.get(url, params=params)
        data = response.json()
        
        if not data:
            print(f"No data for {symbol}")
            continue
            
        df = pd.DataFrame(data)
        df_clean = df[[
            "cik",
            "symbol",
            "companyName",
            "sector",
            "industry",
            "exchange",
            "country",
            "currency",
            "marketCap",
            "ipoDate",
            "isActivelyTrading",
            "isEtf",
            "isAdr",
            "isFund"
        ]].rename(columns={
            "symbol":            "ticker",
            "companyName":       "name",
            "marketCap":         "market_cap",
            "ipoDate":           "ipo_date",
            "isActivelyTrading": "is_active",
            "isEtf":             "is_etf",
            "isAdr":             "is_adr",
            "isFund":            "is_fund"
        })
        dfs.append(df_clean)
    
    return pd.concat(dfs, ignore_index=True)

# %%
df = pd.read_csv('companies.csv')
df = df.drop(columns=["Unnamed: 0"])
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   cik         101 non-null    int64
#  1   ticker      101 non-null    str
#  2   name        101 non-null    str
#  3   sector      101 non-null    str
#  4   industry    101 non-null    str
#  5   exchange    101 non-null    str
#  6   country     101 non-null    str
#  7   currency    101 non-null    str
#  8   market_cap  101 non-null    float64
#  9   ipo_date    101 non-null    str
#  10  is_active   101 non-null    bool
#  11  is_etf      101 non-null    bool
#  12  is_adr      101 non-null    bool
#  13  is_fund     101 non-null    bool
# dtypes: bool(4), float64(1), int64(1), str(8)
# memory usage: 16.2 KB

# %%
df.to_sql("companies", con=engine, if_exists="append", index=False)
print(f"Inserted {len(df_clean)} rows!")
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:196, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     189 def do_executemany(
#     190     self,
#     191     cursor: DBAPICursor,
#    (...)    194     context: Optional[ExecutionContext] = None,
#     195 ) -> None:
# --> 196     rowcount = cursor.executemany(statement, parameters)
#     197     if context is not None:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pymysql/cursors.py:182, in Cursor.executemany(self, query, args)
#     181     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 182     return self._do_execute_many(
#     183         q_prefix,
#     184         q_values,
#     185         q_postfix,
#     186         args,
#     187         self.max_stmt_length,
#     188         self._get_db().encoding,
#     189     )
#     191 self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pymysql/cursors.py:220, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     219     sql += v
# --> 220 rows += self.execute(sql + postfix)
#     221 self.rowcount = rows
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pymysql/connections.py:575, in Connection.query(self, sql, unbuffered)
#     574 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 575 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     576 return self._affected_rows
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pymysql/connections.py:826, in Connection._read_query_result(self, unbuffered)
#     825 else:
# --> 826     result.read()
#     827 self._result = result
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pymysql/connections.py:1203, in MySQLResult.read(self)
#    1202 try:
# -> 1203     first_packet = self.connection._read_packet()
#    1205     if first_packet.is_ok_packet():
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pymysql/connections.py:782, in Connection._read_packet(self, packet_type)
#     781         self._result.unbuffered_active = False
# --> 782     packet.raise_for_error()
#     783 return packet
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pymysql/protocol.py:219, in MysqlPacket.raise_for_error(self)
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pymysql/err.py:150, in raise_mysql_exception(data)
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# IntegrityError: (1062, "Duplicate entry '1652044' for key 'companies.PRIMARY'")
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pandas/io/sql.py:1679, in SQLDatabase.execute(self, sql, params)
#    1678 try:
# -> 1679     return execute_function(sql, *args)
#    1680 except SQLAlchemyError as exc:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/sqlalchemy/sql/elements.py:527, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     526         assert isinstance(self, Executable)
# --> 527     return connection._execute_clauseelement(
#     528         self, distilled_params, execution_options
#     529     )
#     530 else:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)   1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2363, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2362     assert sqlalchemy_exception is not None
# -> 2363     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2364 else:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/sqlalchemy/dialects/mysql/mysqldb.py:196, in MySQLDialect_mysqldb.do_executemany(self, cursor, statement, parameters, context)
#     189 def do_executemany(
#     190     self,
#     191     cursor: DBAPICursor,
#    (...)    194     context: Optional[ExecutionContext] = None,
#     195 ) -> None:
# --> 196     rowcount = cursor.executemany(statement, parameters)
#     197     if context is not None:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pymysql/cursors.py:182, in Cursor.executemany(self, query, args)
#     181     assert q_values[0] == "(" and q_values[-1] == ")"
# --> 182     return self._do_execute_many(
#     183         q_prefix,
#     184         q_values,
#     185         q_postfix,
#     186         args,
#     187         self.max_stmt_length,
#     188         self._get_db().encoding,
#     189     )
#     191 self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pymysql/cursors.py:220, in Cursor._do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     219     sql += v
# --> 220 rows += self.execute(sql + postfix)
#     221 self.rowcount = rows
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pymysql/cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pymysql/cursors.py:322, in Cursor._query(self, q)
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pymysql/connections.py:575, in Connection.query(self, sql, unbuffered)
#     574 self._execute_command(COMMAND.COM_QUERY, sql)
# --> 575 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     576 return self._affected_rows
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pymysql/connections.py:826, in Connection._read_query_result(self, unbuffered)
#     825 else:
# --> 826     result.read()
#     827 self._result = result
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pymysql/connections.py:1203, in MySQLResult.read(self)
#    1202 try:
# -> 1203     first_packet = self.connection._read_packet()
#    1205     if first_packet.is_ok_packet():
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pymysql/connections.py:782, in Connection._read_packet(self, packet_type)
#     781         self._result.unbuffered_active = False
# --> 782     packet.raise_for_error()
#     783 return packet
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pymysql/protocol.py:219, in MysqlPacket.raise_for_error(self)
#     218     print("errno =", errno)
# --> 219 err.raise_mysql_exception(self._data)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pymysql/err.py:150, in raise_mysql_exception(data)
#     149     errorclass = InternalError if errno < 1000 else OperationalError
# --> 150 raise errorclass(errno, errval)
#
# IntegrityError: (pymysql.err.IntegrityError) (1062, "Duplicate entry '1652044' for key 'companies.PRIMARY'")
# [SQL: INSERT INTO companies (cik, ticker, name, sector, industry, exchange, country, currency, market_cap, ipo_date, is_active, is_etf, is_adr, is_fund) VALUES (%(cik)s, %(ticker)s, %(name)s, %(sector)s, %(industry)s, %(exchange)s, %(country)s, %(currency)s, %(market_cap)s, %(ipo_date)s, %(is_active)s, %(is_etf)s, %(is_adr)s, %(is_fund)s)]
# [parameters: [{'cik': 1045810, 'ticker': 'NVDA', 'name': 'NVIDIA Corporation', 'sector': 'Technology', 'industry': 'Semiconductors', 'exchange': 'NASDAQ', 'country': 'US', 'currency': 'USD', 'market_cap': 4339900823748.0, 'ipo_date': '1999-01-22', 'is_active': 1, 'is_etf': 0, 'is_adr': 0, 'is_fund': 0}, {'cik': 1652044, 'ticker': 'GOOGL', 'name': 'Alphabet Inc.', 'sector': 'Communication Services', 'industry': 'Internet Content & Information', 'exchange': 'NASDAQ', 'country': 'US', 'currency': 'USD', 'market_cap': 3715352009576.0, 'ipo_date': '2004-08-19', 'is_active': 1, 'is_etf': 0, 'is_adr': 0, 'is_fund': 0}, {'cik': 1652044, 'ticker': 'GOOG', 'name': 'Alphabet Inc.', 'sector': 'Communication Services', 'industry': 'Internet Content & Information', 'exchange': 'NASDAQ', 'country': 'US', 'currency': 'USD', 'market_cap': 3698415964394.0, 'ipo_date': '2004-08-19', 'is_active': 1, 'is_etf': 0, 'is_adr': 0, 'is_fund': 0}, {'cik': 320193, 'ticker': 'AAPL', 'name': 'Apple Inc.', 'sector': 'Technology', 'industry': 'Consumer Electronics', 'exchange': 'NASDAQ', 'country': 'US', 'currency': 'USD', 'market_cap': 3659195541443.001, 'ipo_date': '1980-12-12', 'is_active': 1, 'is_etf': 0, 'is_adr': 0, 'is_fund': 0}, {'cik': 789019, 'ticker': 'MSFT', 'name': 'Microsoft Corporation', 'sector': 'Technology', 'industry': 'Software - Infrastructure', 'exchange': 'NASDAQ', 'country': 'US', 'currency': 'USD', 'market_cap': 2888718582600.0, 'ipo_date': '1986-03-13', 'is_active': 1, 'is_etf': 0, 'is_adr': 0, 'is_fund': 0}, {'cik': 1018724, 'ticker': 'AMZN', 'name': 'Amazon.com, Inc.', 'sector': 'Consumer Cyclical', 'industry': 'Specialty Retail', 'exchange': 'NASDAQ', 'country': 'US', 'currency': 'USD', 'market_cap': 2241129430030.0, 'ipo_date': '1997-05-15', 'is_active': 1, 'is_etf': 0, 'is_adr': 0, 'is_fund': 0}, {'cik': 1326801, 'ticker': 'META', 'name': 'Meta Platforms, Inc.', 'sector': 'Communication Services', 'industry': 'Internet Content & Information', 'exchange': 'NASDAQ', 'country': 'US', 'currency': 'USD', 'market_cap': 1529486434292.0, 'ipo_date': '2012-05-18', 'is_active': 1, 'is_etf': 0, 'is_adr': 0, 'is_fund': 0}, {'cik': 1730168, 'ticker': 'AVGO', 'name': 'Broadcom Inc.', 'sector': 'Technology', 'industry': 'Semiconductors', 'exchange': 'NASDAQ', 'country': 'US', 'currency': 'USD', 'market_cap': 1516448855151.0, 'ipo_date': '2009-08-06', 'is_active': 1, 'is_etf': 0, 'is_adr': 0, 'is_fund': 0}  ... displaying 10 of 101 total bound parameter sets ...  {'cik': 1069183, 'ticker': 'AXON', 'name': 'Axon Enterprise, Inc.', 'sector': 'Industrials', 'industry': 'Aerospace & Defense', 'exchange': 'NASDAQ', 'country': 'US', 'currency': 'USD', 'market_cap': 40374104432.0, 'ipo_date': '2001-06-19', 'is_active': 1, 'is_etf': 0, 'is_adr': 0, 'is_fund': 0}, {'cik': 35527, 'ticker': 'FITB', 'name': 'Fifth Third Bancorp', 'sector': 'Financial Services', 'industry': 'Banks - Regional', 'exchange': 'NASDAQ', 'country': 'US', 'currency': 'USD', 'market_cap': 29170675035.0, 'ipo_date': '1980-03-17', 'is_active': 1, 'is_etf': 0, 'is_adr': 0, 'is_fund': 0}]]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.to_sql("companies", con=engine, if_exists="append", index=False)
#       2 print(f"Inserted {len(df_clean)} rows!")
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pandas/core/generic.py:3052, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2820 """
#    2821 Write records stored in a DataFrame to a SQL database.
#    2822
#    (...)   3048 3
#    3049 """  # noqa: E501
#    3050 from pandas.io import sql
# -> 3052 return sql.to_sql(
#    3053     self,
#    3054     name,
#    3055     con,
#    3056     schema=schema,
#    3057     if_exists=if_exists,
#    3058     index=index,
#    3059     index_label=index_label,
#    3060     chunksize=chunksize,
#    3061     dtype=dtype,
#    3062     method=method,
#    3063 )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pandas/io/sql.py:841, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     836     raise NotImplementedError(
#     837         "'frame' argument should be either a Series or a DataFrame"
#     838     )
#     840 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 841     return pandas_sql.to_sql(
#     842         frame,
#     843         name,
#     844         if_exists=if_exists,
#     845         index=index,
#     846         index_label=index_label,
#     847         schema=schema,
#     848         chunksize=chunksize,
#     849         dtype=dtype,
#     850         method=method,
#     851         engine=engine,
#     852         **engine_kwargs,
#     853     )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pandas/io/sql.py:2037, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2025 sql_engine = get_engine(engine)
#    2027 table = self.prep_table(
#    2028     frame=frame,
#    2029     name=name,
#    (...)   2034     dtype=dtype,
#    2035 )
# -> 2037 total_inserted = sql_engine.insert_records(
#    2038     table=table,
#    2039     con=self.con,
#    2040     frame=frame,
#    2041     name=name,
#    2042     index=index,
#    2043     schema=schema,
#    2044     chunksize=chunksize,
#    2045     method=method,
#    2046     **engine_kwargs,
#    2047 )
#    2049 self.check_case_sensitive(name=name, schema=schema)
#    2050 return total_inserted
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pandas/io/sql.py:1571, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1568 from sqlalchemy import exc
#    1570 try:
# -> 1571     return table.insert(chunksize=chunksize, method=method)
#    1572 except exc.StatementError as err:
#    1573     # GH34431
#    1574     # https://stackoverflow.com/a/67358288/6067848
#    1575     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1576     )|inf can not be used with MySQL"""
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pandas/io/sql.py:1122, in SQLTable.insert(self, chunksize, method)
#    1117     break
#    1119 chunk_iter = zip(
#    1120     *(arr[start_i:end_i] for arr in data_list), strict=True
#    1121 )
# -> 1122 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1123 # GH 46891
#    1124 if num_inserted is not None:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pandas/io/sql.py:1014, in SQLTable._execute_insert(self, conn, keys, data_iter)
#    1002 """
#    1003 Execute SQL statement inserting data
#    1004
#    (...)   1011    Each item contains a list of values to be inserted
#    1012 """
#    1013 data = [dict(zip(keys, row, strict=True)) for row in data_iter]
# -> 1014 result = self.pd_sql.execute(self.table.insert(), data)
#    1015 return result.rowcount
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/finance-db/lib/python3.13/site-packages/pandas/io/sql.py:1681, in SQLDatabase.execute(self, sql, params)
#    1679     return execute_function(sql, *args)
#    1680 except SQLAlchemyError as exc:
# -> 1681     raise DatabaseError(f"Execution failed on sql '{sql}': {exc}") from exc
#
# DatabaseError: Execution failed on sql 'INSERT INTO companies (cik, ticker, name, sector, industry, exchange, country, currency, market_cap, ipo_date, is_active, is_etf, is_adr, is_fund) VALUES (:cik, :ticker, :name, :sector, :industry, :exchange, :country, :currency, :market_cap, :ipo_date, :is_active, :is_etf, :is_adr, :is_fund)': (pymysql.err.IntegrityError) (1062, "Duplicate entry '1652044' for key 'companies.PRIMARY'")
# [SQL: INSERT INTO companies (cik, ticker, name, sector, industry, exchange, country, currency, market_cap, ipo_date, is_active, is_etf, is_adr, is_fund) VALUES (%(cik)s, %(ticker)s, %(name)s, %(sector)s, %(industry)s, %(exchange)s, %(country)s, %(currency)s, %(market_cap)s, %(ipo_date)s, %(is_active)s, %(is_etf)s, %(is_adr)s, %(is_fund)s)]
# [parameters: [{'cik': 1045810, 'ticker': 'NVDA', 'name': 'NVIDIA Corporation', 'sector': 'Technology', 'industry': 'Semiconductors', 'exchange': 'NASDAQ', 'country': 'US', 'currency': 'USD', 'market_cap': 4339900823748.0, 'ipo_date': '1999-01-22', 'is_active': 1, 'is_etf': 0, 'is_adr': 0, 'is_fund': 0}, {'cik': 1652044, 'ticker': 'GOOGL', 'name': 'Alphabet Inc.', 'sector': 'Communication Services', 'industry': 'Internet Content & Information', 'exchange': 'NASDAQ', 'country': 'US', 'currency': 'USD', 'market_cap': 3715352009576.0, 'ipo_date': '2004-08-19', 'is_active': 1, 'is_etf': 0, 'is_adr': 0, 'is_fund': 0}, {'cik': 1652044, 'ticker': 'GOOG', 'name': 'Alphabet Inc.', 'sector': 'Communication Services', 'industry': 'Internet Content & Information', 'exchange': 'NASDAQ', 'country': 'US', 'currency': 'USD', 'market_cap': 3698415964394.0, 'ipo_date': '2004-08-19', 'is_active': 1, 'is_etf': 0, 'is_adr': 0, 'is_fund': 0}, {'cik': 320193, 'ticker': 'AAPL', 'name': 'Apple Inc.', 'sector': 'Technology', 'industry': 'Consumer Electronics', 'exchange': 'NASDAQ', 'country': 'US', 'currency': 'USD', 'market_cap': 3659195541443.001, 'ipo_date': '1980-12-12', 'is_active': 1, 'is_etf': 0, 'is_adr': 0, 'is_fund': 0}, {'cik': 789019, 'ticker': 'MSFT', 'name': 'Microsoft Corporation', 'sector': 'Technology', 'industry': 'Software - Infrastructure', 'exchange': 'NASDAQ', 'country': 'US', 'currency': 'USD', 'market_cap': 2888718582600.0, 'ipo_date': '1986-03-13', 'is_active': 1, 'is_etf': 0, 'is_adr': 0, 'is_fund': 0}, {'cik': 1018724, 'ticker': 'AMZN', 'name': 'Amazon.com, Inc.', 'sector': 'Consumer Cyclical', 'industry': 'Specialty Retail', 'exchange': 'NASDAQ', 'country': 'US', 'currency': 'USD', 'market_cap': 2241129430030.0, 'ipo_date': '1997-05-15', 'is_active': 1, 'is_etf': 0, 'is_adr': 0, 'is_fund': 0}, {'cik': 1326801, 'ticker': 'META', 'name': 'Meta Platforms, Inc.', 'sector': 'Communication Services', 'industry': 'Internet Content & Information', 'exchange': 'NASDAQ', 'country': 'US', 'currency': 'USD', 'market_cap': 1529486434292.0, 'ipo_date': '2012-05-18', 'is_active': 1, 'is_etf': 0, 'is_adr': 0, 'is_fund': 0}, {'cik': 1730168, 'ticker': 'AVGO', 'name': 'Broadcom Inc.', 'sector': 'Technology', 'industry': 'Semiconductors', 'exchange': 'NASDAQ', 'country': 'US', 'currency': 'USD', 'market_cap': 1516448855151.0, 'ipo_date': '2009-08-06', 'is_active': 1, 'is_etf': 0, 'is_adr': 0, 'is_fund': 0}  ... displaying 10 of 101 total bound parameter sets ...  {'cik': 1069183, 'ticker': 'AXON', 'name': 'Axon Enterprise, Inc.', 'sector': 'Industrials', 'industry': 'Aerospace & Defense', 'exchange': 'NASDAQ', 'country': 'US', 'currency': 'USD', 'market_cap': 40374104432.0, 'ipo_date': '2001-06-19', 'is_active': 1, 'is_etf': 0, 'is_adr': 0, 'is_fund': 0}, {'cik': 35527, 'ticker': 'FITB', 'name': 'Fifth Third Bancorp', 'sector': 'Financial Services', 'industry': 'Banks - Regional', 'exchange': 'NASDAQ', 'country': 'US', 'currency': 'USD', 'market_cap': 29170675035.0, 'ipo_date': '1980-03-17', 'is_active': 1, 'is_etf': 0, 'is_adr': 0, 'is_fund': 0}]]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
